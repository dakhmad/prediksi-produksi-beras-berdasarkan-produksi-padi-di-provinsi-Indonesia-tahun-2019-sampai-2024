# %% [markdown]
# # UTS Machine Learning Semester 6
# ## **Prediksi Produksi Beras Berdasarkan Produksi Padi Menggunakan Regresi Linear**
#
# ![Image 169 (5).png](data:image/png;base64,...)

# %% [markdown]
# **Main goals in this notebook**
#
# Segala puji bagi Allah SWT atas segala rahmat-Nya. Shalawat serta salam kita haturkan kepada Nabi Muhammad saw. *Alhamdulillah*, pada notebook dani_ml_prediksi_produksi_beras_regresi_linear.ipynb ini dapat terselesaikan dengan izin-Nya. Sebuah notebook yang dibuat dengan tujuan memenuhi tugas UTS Machine Learning serta menerapkan ilmu yang dipelajari terkait Machine Learning.
#
#
# ---

# %% [markdown]
# ##**1. Business Understanding**

# %% [markdown]
# ###a. Menentukan masalah bisnis
# **Judul Penelitian:**
# Prediksi Produksi Beras Berdasarkan Produksi Padi Menggunakan Regresi Linear
#
# **Masalah Bisnis:**
# Produksi beras merupakan faktor krusial bagi ketahanan pangan Indonesia. Namun, fluktuasi dalam produksi padi sering kali menyulitkan perencanaan produksi beras secara nasional dan daerah. Keterlambatan atau ketidakakuratan dalam memproyeksikan jumlah beras yang dihasilkan dari padi dapat berdampak pada:
# * Distribusi beras tidak merata.
# * Lonjakan harga karena kekurangan pasokan.
# * Kegagalan dalam mencapai target swasembada beras nasional.
#
# **Tujuan Penelitian:**
# Membangun model prediksi produksi beras berdasarkan data produksi padi menggunakan algoritma regresi linear. Model ini akan membantu:
# * Pemerintah atau dinas pertanian memprediksi produksi beras lebih awal.
# * Mengoptimalkan distribusi dan logistik.
# * Membantu perumusan kebijakan pertanian secara lebih berbasis data.
#
# **Kriteria Kesuksesan:**
# * Model regresi linear dibangun dengan akurasi tinggi.
# * Model mampu memprediksi produksi beras dari input produksi padi untuk provinsi-provinsi di Indonesia dengan galat prediksi rendah (RMSE kecil).
# * Model mudah digunakan kembali oleh stakeholder (misalnya: dinas pertanian atau pengambil kebijakan).
# * Hasil visualisasi dan prediksi dapat membantu proses pengambilan keputusan.

# %% [markdown]
# ###b. Menentukan tugas analitik untuk menyelesaikan masalah
#
# **Jenis Tugas Analitik:**
# Regresi
#
# **Penjelasan:**
# Tugas analitik dari studi ini adalah memprediksi nilai kontinu (produksi beras dalam ton) berdasarkan nilai input lainnya (produksi padi dalam ton). Ini termasuk ke dalam kategori supervised learning dengan metode regresi, karena:
# * Target (label/output) yaitu Produksi Beras bersifat numerik dan kontinu.
# * Fitur (input) yaitu Produksi Padi tersedia dalam dataset.
# * Kita ingin mempelajari hubungan matematis antara input dan output.
#
# **Kenapa Regresi Linear?**
# * Relasi antara jumlah padi dan beras secara logika bersifat linier (beras dihasilkan dari padi).
# * Interpretasinya mudah dan cocok untuk kasus prediksi sederhana.
# * Cocok sebagai baseline model sebelum mencoba model yang lebih kompleks.

# %% [markdown]
# ###c. Menentukan kebutuhan data
# ####**Sumber dataset Produksi Padi dan Beras Menurut Provinsi, 2019-2024?**
#
# Dataset "Produksi Padi dan Beras Menurut Provinsi, 2019-2024.xlsx"  didapatkan melalui pencarian dataset pada website [Badan Statistik Pusat (BPS)](https://www.bps.go.id/id) dengan kata kunci pencarian "produksi padi dan beras" atau dapat diakses pada link dataset di bawah:
# * [Produksi Padi dan Beras Menurut Provinsi, 2019.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2019)
# * [Produksi Padi dan Beras Menurut Provinsi, 2020.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2020)
# * [Produksi Padi dan Beras Menurut Provinsi, 2021.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2021)
# * [Produksi Padi dan Beras Menurut Provinsi, 2022.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2022)
# * [Produksi Padi dan Beras Menurut Provinsi, 2023.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2023)
# * [Produksi Padi dan Beras Menurut Provinsi, 2024.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2024)
#
# Atau bisa kunjungi dataset tersebut pada halaman Kaggle saya
#
# [Dataset "Produksi Padi dan Beras Menurut Provinsi, 2019-2024"](https://www.kaggle.com/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/data)
#
#
#
# ####**Terkait dataset**
#
# Informasi singkat, dataset Produksi Padi dan Beras Menurut Provinsi ini memiliki 3 kolom dan  beberapa baris yang mengandung beberapa fitur seperti Provinsi, Produksi Padi - Produksi Padi (ton) (Ton), dan Produksi Padi - Produksi Beras (ton) (Ton). Kemudian, untuk detail informasi fitur yang tersedia pada dataset adalah sebagai berikut:
# * **Provinsi**: nama provinsi
# * **Produksi Padi - Produksi Padi (ton) (Ton)**: banyak produksi padi dalam ton
# * **Produksi Padi - Produksi Beras (ton) (Ton)**: banyak produksi beras dalam ton

# %% [markdown]
# ###d. Manajemen proyek pelaksanaan penelitian
#
# #### **Gant Chart Penelitian Machine Learning**
# ![Cuplikan layar 2025-06-01 165247.png](data:image/png;base64,...)
#
#
#
# ---

# %% [markdown]
# ##**2. Data Understanding**

# %% [markdown]
# ###a. Mencari dataset
# Link dataset didapatkan pada website [Badan Pusat Statistik (BPS) Indonesia](https://www.bps.go.id/id), kemudian berikut adalah dataset yang dimaksud:
# * [Produksi Padi dan Beras Menurut Provinsi, 2019.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2019)
# * [Produksi Padi dan Beras Menurut Provinsi, 2020.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2020)
# * [Produksi Padi dan Beras Menurut Provinsi, 2021.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2021)
# * [Produksi Padi dan Beras Menurut Provinsi, 2022.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2022)
# * [Produksi Padi dan Beras Menurut Provinsi, 2023.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2023)
# * [Produksi Padi dan Beras Menurut Provinsi, 2024.xlsx](https://www.bps.go.id/id/statistics-table/3/ZDNaak0yODBUVTlGYW5sa2REUkVUVVY1YVZkbmR6MDkjMyMwMDAw/produksi-padi-sup-1-sup-dan-beras-menurut-provinsi.html?year=2024)
#
# Dataset ini digunakan sebagai sumber utama dalam penelitian karena mengandung informasi kuantitatif yang diperlukan, seperti:
# * Nama Provinsi
# * Produksi Padi (dalam ton)
# * Produksi Beras (dalam ton)
#
# Data ini sangat relevan untuk mendukung tujuan analisis dan prediksi dalam studi kasus **"Prediksi Produksi Beras Berdasarkan Produksi Padi Menggunakan Regresi Linear"**.

# %% [markdown]
# ###b. Deskripsi dataset

# %% [markdown]
# Membaca dan menggabungkan datasets
#
# 1. Import library pandas untuk operasi pembacaan dataset dan pengubah atau pengatur bentuk dataset.
# 2. Membaca dan menggabungkan dataset yang terpisah dengan memanfaatkan perulangan for yang memasukkan satu-satu dataset ke dalam datasets kumpulan.
# 3. Menampilkan 10 data teratas

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/produksi-padi-dan-beras-menurut-provinsi-2019-2024

# %%
# 1: Import library pandas
import pandas as pd

# 2: Membaca dan menggabungkan datasets
path_2019 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2019.xlsx'
path_2020 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2020.xlsx'
path_2021 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2021.xlsx'
path_2022 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2022.xlsx'
path_2023 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2023.xlsx'
path_2024 = '/root/.cache/kagglehub/datasets/daniakhmadmaulana/produksi-padi-dan-beras-menurut-provinsi-2019-2024/versions/1/Produksi Padi dan Beras Menurut Provinsi 2024.xlsx'

datasets = [
    path_2019,
    path_2020,
    path_2021,
    path_2022,
    path_2023,
    path_2024,
]

df = pd.DataFrame()

# perulangan untuk menggabungkan datasets
for dataset in datasets:
    df_temp = pd.read_excel(dataset)
    df = pd.concat([df, df_temp], ignore_index=True)

# 3: Menampilkan 10 data teratas
df.head(10)
# Out:
#                     Provinsi  Produksi Padi - Produksi Padi (ton) (Ton)  \
# 0                       Aceh                                 1714437.60
# 1             Sumatera Utara                                 2078901.59
# 2             Sumatera Barat                                 1482996.01
# 3                       Riau                                  230873.97
# 4                      Jambi                                  309932.68
# 5           Sumatera Selatan                                 2603396.24
# 6                   Bengkulu                                  296472.07
# 7                    Lampung                                 2164089.33
# 8  Kepulauan Bangka Belitung                                   48805.68
# 9             Kepulauan Riau                                    1150.80
#
#    Produksi Padi - Produksi Beras (ton) (Ton)
# 0                                   982570.32
# 1                                  1186348.96
# ...

# %% [markdown]
# Melihat type data pada kolom dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 3 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Provinsi                                    231 non-null    object
#  1   Produksi Padi - Produksi Padi (ton) (Ton)   218 non-null    float64
#  2   Produksi Padi - Produksi Beras (ton) (Ton)  218 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.6+ KB

# %% [markdown]
# Melihat informasi dengan statistik deskriptif pada dataset

# %%
df.describe()
# Out:
#        Produksi Padi - Produksi Padi (ton) (Ton)  \
# count                               2.180000e+02
# mean                                2.986617e+06
# std                                 9.016231e+06
# min                                 4.238000e+01
# 25%                                 2.145326e+05
# 50%                                 5.267125e+05
# 75%                                 1.626791e+06
# max                                 5.474898e+07
#
#        Produksi Padi - Produksi Beras (ton) (Ton)
# count                                2.180000e+02
# mean                                 1.718042e+06
# std                                  5.186572e+06
# min                                  2.420000e+01
# 25%                                  1.230098e+05
# 50%                                  2.977465e+05
# 75%                                  9.316356e+05
# max                                  3.154052e+07

# %% [markdown]
# **count:** Jumlah total nilai non-missing (bukan NAN) dalam setiap kolom.
#
# **mean:** Rata-rata nilai dari setiap kolom.
#
# **std:** Standar Deviasi atau simpangan baku.
#
# **min:** Nilai minimum atau nilai terkecil pada setiap kolom.
#
# **25%:** Kuartil pertama.
#
# **50%:** Kuartil kedua.
#
# **75%:** Kuartil ketiga.
#
# **max:** Nilai maksimum atau nilai terbesar pada setiap kolom.

# %% [markdown]
# Cek nilai kosong atau missing-value (NAN)

# %%
df.isnull().sum()
# Out:
# Provinsi                                       4
# Produksi Padi - Produksi Padi (ton) (Ton)     17
# Produksi Padi - Produksi Beras (ton) (Ton)    17
# dtype: int64

# %% [markdown]
# Terdapat beberapa data null atau kosong pada dataset, hal ini karena dalam dataset terdapat catatan atau baris kosong yang disisipkan oleh pembuat dataset, sehingga perlu pembersihan data di tahap selanjutnya.

# %% [markdown]
# ###c. Visualisasi dataset

# %% [markdown]
# Import library matplotlib dan seaborn untuk visualisasi grafik.

# %%
# 1: Import library matplotlib dan seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Menampilkan korelasi kolom produksi padi dan produksi beras

# %%
# Grafik Korelasi Produksi Padi dan Produksi Beras
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df,
    x='Produksi Padi - Produksi Padi (ton) (Ton)',
    y='Produksi Padi - Produksi Beras (ton) (Ton)'
)
plt.title("Scatter Plot: Produksi Padi vs Produksi Beras")
plt.xlabel("Produksi Padi (ton)")
plt.ylabel("Produksi Beras (ton)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Terlihat pada grafik di atas, terdapat nilai outlier yang perlu di bersihkan di tahap selanjutnya, hal ini karena pada dataset terdapat data yang merupakan total dari kolom produksi padi dan produksi beras, sehingga ketika ditampilkan atau visualisasikan menggunakan Scatter Plot, terlihat ada data yang rentangnya sangat jauh dari kebanyakan data.

# %% [markdown]
# Melihat distribusi produksi padi dan produksi beras menggunakan histogram

# %%
# Grafik Distribusi Produksi Padi
plt.figure(figsize=(8,5))
plt.subplot(1, 2, 1)
sns.histplot(df['Produksi Padi - Produksi Padi (ton) (Ton)'], bins=30, kde=True)
plt.title("Distribusi Produksi Padi (ton)")
plt.xlabel("Produksi Padi (ton)")
plt.ylabel("Frekuensi")
plt.tight_layout()

# Grafik Distribusi Produksi Beras
plt.subplot(1, 2, 2)
sns.histplot(df['Produksi Padi - Produksi Beras (ton) (Ton)'], bins=30, kde=True)
plt.title("Distribusi Produksi Beras (ton)")
plt.xlabel("Produksi Beras (ton)")
plt.ylabel("Frekuensi")
plt.tight_layout()
plt.show()

# %% [markdown]
# Histogram produksi padi dan beras menunjukkan distribusi produksi per provinsi.
#
#
# ---

# %% [markdown]
# ##**3. Praprocessing Data**

# %% [markdown]
# Pada bagian praprocessing data, akan dilakukan pembersihan data untuk bisa diolah pada tahap selanjutnya. Pembersihan yang dimaksud adalah menangani data-data seperti data duplikat, data null, dan data outlier.

# %% [markdown]
# ####**Tujuan dan Alasan Pemilihan Fitur:**
#
# Dalam studi kasus "Prediksi Produksi Beras Berdasarkan Produksi Padi", maka:
#
# * Fitur utama (X): Produksi Padi - Produksi Padi (ton) (Ton) — sebagai input/variabel prediktor.
#
# * Target (y): Produksi Padi - Produksi Beras (ton) (Ton) — sebagai output/variabel yang ingin diprediksi.
#
# Tidak memakai kolom "Provinsi" karena:
#
# * Data numeriknya tidak dipengaruhi secara langsung oleh nama provinsi.
#
# * Model regresi linear fokus pada hubungan numerik antar fitur, bukan kategori daerah.

# %%
# Rename kolom agar lebih mudah digunakan
df.rename(columns={
    'Produksi Padi - Produksi Padi (ton) (Ton)': 'Produksi_Padi',
    'Produksi Padi - Produksi Beras (ton) (Ton)': 'Produksi_Beras'
}, inplace=True)

df.head(10)
# Out:
#                     Provinsi  Produksi_Padi  Produksi_Beras
# 0                       Aceh     1714437.60       982570.32
# 1             Sumatera Utara     2078901.59      1186348.96
# 2             Sumatera Barat     1482996.01       854265.01
# 3                       Riau      230873.97       131816.96
# 4                      Jambi      309932.68       178364.34
# 5           Sumatera Selatan     2603396.24      1487312.32
# 6                   Bengkulu      296472.07       169877.68
# 7                    Lampung     2164089.33      1237624.46
# 8  Kepulauan Bangka Belitung       48805.68        28779.62
# 9             Kepulauan Riau        1150.80          655.15

# %% [markdown]
# **Cek dan drop data duplikat**
#
# Pada kode di bawah, terlihat bahwa data duplikat yang ada adalah data yang disisipkan oleh pembuat dataset berupa baris kosong dan teks catatan di bawah akhir dataset.

# %%
# Menampung data duplikat
duplicates_boolean_series = df.duplicated(keep=False)
duplicated_rows = df[duplicates_boolean_series]

# Cetak baris-baris yang duplikat
print("Baris data yang terduplikasi:")
print(duplicated_rows)

print("\nJumlah baris sebelum menghapus data duplikat:", len(df))
print("\nJumlah baris yang merupakan data duplikat:", duplicates_boolean_series.sum())

# Hapus data duplikat
df.drop_duplicates(inplace=True)

# Cek jumlah
print("\nJumlah baris setelah menghapus data duplikat:", len(df))
# Out:
# Baris data yang terduplikasi:
#     Provinsi  Produksi_Padi  Produksi_Beras
# 35       NaN            NaN             NaN
# 36   Catatan            NaN             NaN
# 73       NaN            NaN             NaN
# 74   Catatan            NaN             NaN
# 112      NaN            NaN             NaN
# 113  Catatan            NaN             NaN
# 154      NaN            NaN             NaN
# 155  Catatan            NaN             NaN
#
# Jumlah baris sebelum menghapus data duplikat: 235
#
# Jumlah baris yang merupakan data duplikat: 8
#
# Jumlah baris setelah menghapus data duplikat: 229

# %% [markdown]
# **Cek dan drop data null (NAN)**
#
# Seperti pada penjelasan sebelumnya, dataset memiliki beberapa baris data yang NAN, hal ini karena terjadinya penyisipan baris kosong dan catatan di baris paling bawah, juga ada beberapa provinsi yang tidak memiliki data produksi padi atau beras. Bisa dilihat pada penampilan di bawah.

# %%
df.tail(10)
# Out:
#              Provinsi  Produksi_Padi  Produksi_Beras
# 225    Sulawesi Barat      318876.59       183138.80
# 226            Maluku       91125.35        51031.04
# 227      Maluku Utara       31232.95        17478.19
# 228       Papua Barat       20729.15        12455.13
# 229  Papua Barat Daya         988.64          594.02
# 230             Papua        4609.95         2632.19
# 231     Papua Selatan      217789.62       124355.12
# 232      Papua Tengah        6072.38         3467.26
# 233  Papua Pegunungan          42.38           24.20
# 234         Indonesia    53142726.65     30621248.72

# %%
print("Jumlah data null per kolom:")
df.isnull().sum()
# Out:
# Jumlah data null per kolom:
# Provinsi           1
# Produksi_Padi     11
# Produksi_Beras    11
# dtype: int64

# %% [markdown]
# Penanganan data null (NAN)

# %%
# Menghapus data null berdasarkan kolom
df_clean = df.dropna(subset=['Produksi_Padi', 'Produksi_Beras'])

print("\nJumlah baris sebelum menghapus data null:", len(df))
print("\nJumlah baris setelah menghapus data null:", len(df_clean))

# Cek ukuran data sebelum dan sesudah
print("\nUkuran sebelum cleaning:", df.shape)
print("Ukuran sesudah cleaning null:", df_clean.shape)
# Out:
# Jumlah baris sebelum menghapus data null: 229
#
# Jumlah baris setelah menghapus data null: 218
#
# Ukuran sebelum cleaning: (229, 3)
# Ukuran sesudah cleaning null: (218, 3)

# %% [markdown]
# **Penanganan Data Outlier**
#
# Ditangani dengan mendeteksi nilai outlier dan kemudian melakukan filter data.

# %%
# Cek outlier dengan IQR (Interquartile Range)
Q1_padi = df_clean['Produksi_Padi'].quantile(0.25)
Q3_padi = df_clean['Produksi_Padi'].quantile(0.75)
IQR_padi = Q3_padi - Q1_padi

Q1_beras = df_clean['Produksi_Beras'].quantile(0.25)
Q3_beras = df_clean['Produksi_Beras'].quantile(0.75)
IQR_beras = Q3_beras - Q1_beras

# Batas atas & bawah
batas_bawah_padi = Q1_padi - 1.5 * IQR_padi
batas_atas_padi = Q3_padi + 1.5 * IQR_padi

batas_bawah_beras = Q1_beras - 1.5 * IQR_beras
batas_atas_beras = Q3_beras + 1.5 * IQR_beras

# Filter data tanpa outlier
df_final = df_clean[
    (df_clean['Produksi_Padi'] >= batas_bawah_padi) &
    (df_clean['Produksi_Padi'] <= batas_atas_padi) &
    (df_clean['Produksi_Beras'] >= batas_bawah_beras) &
    (df_clean['Produksi_Beras'] <= batas_atas_beras)
]

print("\nUkuran data final (tanpa outlier):", df_final.shape)
# Out:
# Ukuran data final (tanpa outlier): (188, 3)

# %%
# Dataset sudah bersih dan siap pakai untuk tahap selanjutnya
df_final
# Out:
#              Provinsi  Produksi_Padi  Produksi_Beras
# 0                Aceh     1714437.60       982570.32
# 1      Sumatera Utara     2078901.59      1186348.96
# 2      Sumatera Barat     1482996.01       854265.01
# 3                Riau      230873.97       131816.96
# 4               Jambi      309932.68       178364.34
# ..                ...            ...             ...
# 229  Papua Barat Daya         988.64          594.02
# 230             Papua        4609.95         2632.19
# 231     Papua Selatan      217789.62       124355.12
# 232      Papua Tengah        6072.38         3467.26
# 233  Papua Pegunungan          42.38           24.20
#
# [188 rows x 3 columns]

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, 0 to 233
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Provinsi        188 non-null    object
#  1   Produksi_Padi   188 non-null    float64
#  2   Produksi_Beras  188 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# **Visualisasi data final**
#
# Grafik korelasi produksi padi dan produksi beras yang sudah clean atau memakai data final.

# %%
# Grafik Korelasi Produksi Padi dan Produksi Beras
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df_final,
    x='Produksi_Padi',
    y='Produksi_Beras'
)
plt.title("Scatter Plot: Produksi Padi vs Produksi Beras")
plt.xlabel("Produksi Padi (ton)")
plt.ylabel("Produksi Beras (ton)")
plt.tight_layout()
plt.show()

# %% [markdown]
# Menampilkan distribusi data final dengan histogram

# %%
# Grafik Distribusi Produksi Padi
plt.figure(figsize=(8,5))
plt.subplot(1, 2, 1)
sns.histplot(df_final['Produksi_Padi'], bins=30, kde=True)
plt.title("Distribusi Produksi Padi (ton)")
plt.xlabel("Produksi Padi (ton)")
plt.ylabel("Frekuensi")
plt.tight_layout()

# Grafik Distribusi Produksi Beras
plt.subplot(1, 2, 2)
sns.histplot(df_final['Produksi_Beras'], bins=30, kde=True)
plt.title("Distribusi Produksi Beras (ton)")
plt.xlabel("Produksi Beras (ton)")
plt.ylabel("Frekuensi")
plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ##**4. Modelling**

# %%
# Spliting dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_final[['Produksi_Padi']], df_final['Produksi_Beras'], test_size=0.2, random_state=42)

# %%
# Penerapan model Linear Regression
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

# Prediksi
y_pred = model.predict(X_test)

# %%
# Membuat DataFrame baru dari data uji untuk keperluan plot
plot_df = X_test.copy()
plot_df['Produksi_Beras'] = y_test
plot_df['Prediksi_Beras'] = y_pred

# Plot
plt.figure(figsize=(10,6))
plt.scatter(plot_df['Produksi_Padi'], plot_df['Produksi_Beras'], color='blue', label='Data Aktual')
plt.plot(plot_df['Produksi_Padi'], plot_df['Prediksi_Beras'], color='red', label='Regresi Linear')
plt.xlabel('Produksi Padi (ton)')
plt.ylabel('Produksi Beras (ton)')
plt.title('Regresi Linear: Produksi Padi vs Produksi Beras')
plt.legend()
plt.grid(True)
plt.show()

# Hasil model
print("Intercept:", model.intercept_)
print("Koefisien:", model.coef_[0])
# Out:
# Intercept: 825.6546106892638
# Koefisien: 0.5736406066069716

# %%
import pickle

# Simpan model regresi linear yang sudah dilatih ke dalam file
nama_file_model = 'regresi_linear_model.pkl'
with open(nama_file_model, 'wb') as file:
    pickle.dump(model, file)

print(f"\nModel telah berhasil disimpan dengan nama '{nama_file_model}'.")
print("Model ini siap untuk di-deploy!")
# Out:
# Model telah berhasil disimpan dengan nama 'regresi_linear_model.pkl'.
# Model ini siap untuk di-deploy!

# %%
# Download df_final menjadi file csv
df_final.to_csv("df_final.csv", index=False)

# %% [markdown]
# ---

# %% [markdown]
# ##**5. Evaluation**

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Evaluasi model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# Tampilkan hasil evaluasi
print("Evaluasi Model Regresi Linear:")
print(f"MAE : {mae:.2f}")
print(f"MSE : {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R²  : {r2:.2f}")
# Out:
# Evaluasi Model Regresi Linear:
# MAE : 4766.63
# MSE : 48624554.91
# RMSE: 6973.13
# R²  : 1.00

# %% [markdown]
# ---

# %% [markdown]
# ##**6. Deployment**

# %%
import gradio as gr
import pickle
import numpy as np
import pandas as pd

# Muat model
try:
    with open('regresi_linear_model.pkl', 'rb') as file:
        model = pickle.load(file)
except FileNotFoundError:
    print("File model 'regresi_linear_model.pkl' tidak ditemukan.")
    raise

# Muat dataframe
try:
    df_final = pd.read_csv("df_final.csv")
except FileNotFoundError:
    df_final = pd.DataFrame({"Data": ["File df_final.csv tidak ditemukan"]})

# Fungsi prediksi
def prediksi_beras(produksi_padi):
    input_data = np.array([[produksi_padi]])
    prediksi = model.predict(input_data)
    return f"Perkiraan Produksi Beras: {prediksi[0]:,.2f} ton"

# Fungsi untuk menampilkan dataframe
def tampilkan_df():
    return df_final.head(10)

# Komponen prediksi
prediksi_interface = gr.Interface(
    fn=prediksi_beras,
    inputs=gr.Number(label="Produksi Padi (ton)"),
    outputs=gr.Textbox(label="Prediksi Produksi Beras (ton)"),
    title="🌾 Prediksi Produksi Beras",
    description="Masukkan jumlah produksi padi (dalam ton), sistem akan memprediksi hasil produksi beras berdasarkan model regresi linear.",
    allow_flagging="never"
)

# Komponen tabel
tabel_interface = gr.Interface(
    fn=lambda: df_final,
    inputs=[],
    outputs=gr.Dataframe(
        label="Data Produksi",
        datatype="auto",
        interactive=False,
        visible=True,
        row_count=10,
        col_count=(len(df_final.columns) if not df_final.empty else 1)
    ),
    title="📊 Dataset Produksi",
    allow_flagging="never"
)

# Gabungkan dalam tab
demo = gr.TabbedInterface(
    interface_list=[prediksi_interface, tabel_interface],
    tab_names=["Prediksi", "Dataset"]
)

# Jalankan aplikasi
demo.launch()
# Out:
# /usr/local/lib/python3.11/dist-packages/gradio/interface.py:425: UserWarning: The `allow_flagging` parameter in `Interface` is deprecated.Use `flagging_mode` instead.
#   warnings.warn(
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://28861134172214060f.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://28861134172214060f.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
